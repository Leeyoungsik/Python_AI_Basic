# %% [markdown]
# <a href="https://colab.research.google.com/github/Leeyoungsik/Python_AI_Basic/blob/main/ETF_%ED%8F%AC%ED%8A%B8%ED%8F%B4%EB%A6%AC%EC%98%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 환경셋팅

# %%
# (라이브러리 설치 후 런타임 재시작 필요)
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 24 not upgraded.
# Need to get 9,599 kB of archives.
# After this operation, 29.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-nanum all 20180306-3 [9,599 kB]
# Fetched 9,599 kB in 2s (6,394 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 122349 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20180306-3_all.deb ...
# Unpacking fonts-nanum (20180306-3) ...
# Setting up fonts-nanum (20180306-3) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
 # !pip install pykrx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pykrx
#   Downloading pykrx-1.0.41-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.5/125.5 kB 3.9 MB/s eta 0:00:00
# Collecting deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from pykrx) (1.5.3)
# Collecting datetime
#   Downloading DateTime-5.1-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: xlrd in /usr/local/lib/python3.9/dist-packages (from pykrx) (2.0.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from pykrx) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from pykrx) (2.27.1)
# Collecting zope.interface
#   Downloading zope.interface-6.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.1/246.1 kB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.9/dist-packages (from datetime->pykrx) (2022.7.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/dist-packages (from deprecated->pykrx) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->pykrx) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->pykrx) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->pykrx) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->pykrx) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->pykrx) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->pykrx) (1.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from zope.interface->datetime->pykrx) (67.6.1)
# Installing collected packages: zope.interface, deprecated, datetime, pykrx
# Successfully installed datetime-5.1 deprecated-1.2.13 pykrx-1.0.41 zope.interface-6.0

# %%
# !pip install plotly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/dist-packages (5.13.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly) (8.2.2)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Matplotlib 한글 폰트 설정
plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# # pykrx - etf 불러오기
#
# - [kosef200](https://finance.naver.com/item/main.naver?code=069660)

# %%
from pykrx import stock
df = stock.get_etf_ohlcv_by_date("20200101", "20230412", "069660") #KOSEF200
df.head()
# Out:
#                  NAV     시가     고가     저가     종가     거래량         거래대금    기초지수
# 날짜
# 2020-01-02  29868.35  30205  30205  29765  29810   21510    641237230  290.35
# 2020-01-03  29907.47  30155  30220  29695  29810   42305   1266100015  290.74
# 2020-01-06  29670.39  29555  29670  29510  29595  391000  11571121930  288.43
# 2020-01-07  29960.75  29740  29945  29735  29895    1266     37791695  291.23
# 2020-01-08  29774.21  29670  29815  29490  29700   48724   1447388370  289.42

# %%
df['종가'].plot(figsize=(18, 5))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-0fea262eae35> in <cell line: 1>()
# ----> 1 df['종가'].plot(figsize=(18, 5))
#
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     998                     data.columns = label_name
#     999
# -> 1000         return plot_backend.plot(data, kind=kind, **kwargs)
#    1001
#    1002     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     449         self._args_adjust()
#     450         self._compute_plot_data()
# --> 451         self._setup_subplots()
#     452         self._make_plot()
#     453         self._add_table()
#
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py in _setup_subplots(self)
#     511             if self.ax is None:
#     512                 fig = self.plt.figure(figsize=self.figsize)
# --> 513                 axes = fig.add_subplot(111)
#     514             else:
#     515                 fig = self.ax.get_figure()
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#     755             projection_class, pkw = self._process_projection_requirements(
#     756                 *args, **kwargs)
# --> 757             ax = projection_class(self, *args, **pkw)
#     758             key = (projection_class, pkw)
#     759         return self._add_axes_internal(ax, key)
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_base.py in __init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, *args, **kwargs)
#     673
#     674         # this call may differ for non-sep axes, e.g., polar
# --> 675         self._init_axis()
#     676         if facecolor is None:
#     677             facecolor = mpl.rcParams['axes.facecolor']
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_base.py in _init_axis(self)
#     818     def _init_axis(self):
#     819         # This is moved out of __init__ because non-separable axes don't use it
# --> 820         self.xaxis = maxis.XAxis(self)
#     821         self.spines.bottom.register_axis(self.xaxis)
#     822         self.spines.top.register_axis(self.xaxis)
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#    2232
#    2233     def __init__(self, *args, **kwargs):
# -> 2234         super().__init__(*args, **kwargs)
#    2235         self._init()
#    2236
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     452                 "parameter will become keyword-only %(removal)s.",
#     453                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454         return func(*args, **kwargs)
#     455
#     456     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axis.py in __init__(self, axes, pickradius)
#     684         self._minor_tick_kw = dict()
#     685
# --> 686         self.clear()
#     687         self._autoscale_on = True
#     688
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axis.py in clear(self)
#     877         self._init()
#     878
# --> 879         self._set_scale('linear')
#     880
#     881         # Clear the callback registry for this axis, or it may "leak"
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axis.py in _set_scale(self, value, **kwargs)
#     768         else:
#     769             self._scale = value
# --> 770         self._scale.set_default_locators_and_formatters(self)
#     771
#     772         self.isDefault_majloc = True
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/scale.py in set_default_locators_and_formatters(self, axis)
#     104         # docstring inherited
#     105         axis.set_major_locator(AutoLocator())
# --> 106         axis.set_major_formatter(ScalarFormatter())
#     107         axis.set_minor_formatter(NullFormatter())
#     108         # update the minor locator for x and y axis based on rcParams
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/ticker.py in __init__(self, useOffset, useMathText, useLocale)
#     432         self.set_useOffset(useOffset)
#     433         self._usetex = mpl.rcParams['text.usetex']
# --> 434         self.set_useMathText(useMathText)
#     435         self.orderOfMagnitude = 0
#     436         self.format = ''
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/ticker.py in set_useMathText(self, val)
#     547                 try:
#     548                     from matplotlib import font_manager
# --> 549                     ufont = font_manager.findfont(
#     550                         font_manager.FontProperties(
#     551                             mpl.rcParams["font.family"]
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/font_manager.py in findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1257             "font.serif", "font.sans-serif", "font.cursive", "font.fantasy",
#    1258             "font.monospace"])
# -> 1259         ret = self._findfont_cached(
#    1260             prop, fontext, directory, fallback_to_default, rebuild_if_missing,
#    1261             rc_params)
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/font_manager.py in _findfont_cached(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing, rc_params)
#    1425                 _log.info(
#    1426                     'findfont: Found a missing font file.  Rebuilding cache.')
# -> 1427                 new_fm = _load_fontmanager(try_read_cache=False)
#    1428                 # Replace self by the new fontmanager, because users may have
#    1429                 # a reference to this specific instance.
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/font_manager.py in _load_fontmanager(try_read_cache)
#    1541                 return fm
#    1542     fm = FontManager()
# -> 1543     json_dump(fm, fm_path)
#    1544     _log.info("generated new fontManager")
#    1545     return fm
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/font_manager.py in json_dump(data, filename)
#     955     processes from overwriting one another's output.
#     956     """
# --> 957     with cbook._lock_path(filename), open(filename, 'w') as fh:
#     958         try:
#     959             json.dump(data, fh, cls=_JSONEncoder, indent=2)
#
# /usr/lib/python3.9/contextlib.py in __enter__(self)
#     117         del self.args, self.kwds, self.func
#     118         try:
# --> 119             return next(self.gen)
#     120         except StopIteration:
#     121             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/cbook/__init__.py in _lock_path(path)
#    1802     for _ in range(retries):
#    1803         try:
# -> 1804             with lock_path.open("xb"):
#    1805                 break
#    1806         except FileExistsError:
#
# /usr/lib/python3.9/pathlib.py in open(self, mode, buffering, encoding, errors, newline)
#    1250         the built-in open() function does.
#    1251         """
# -> 1252         return io.open(self, mode, buffering, encoding, errors, newline,
#    1253                        opener=self._opener)
#    1254
#
# /usr/lib/python3.9/pathlib.py in _opener(self, name, flags, mode)
#    1118     def _opener(self, name, flags, mode=0o666):
#    1119         # A stub for the opener argument to built-in open()
# -> 1120         return self._accessor.open(self, flags, mode)
#    1121
#    1122     def _raw_open(self, flags, mode=0o777):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/root/.cache/matplotlib/fontlist-v330.json.matplotlib-lock'

# %% [markdown]
# ## 포트폴리오 셋팅하기

# %% [markdown]
# ----
# ### [영구 포트폴리오](https://www.investopedia.com/terms/p/permanent-portfolio.asp)
#
# - 1980년 해리 브라운(Harry Browne)이 고안한 전략
# - 자산을 주식, 금, 채권, 현금으로 4등분하여 보유

# %%
import plotly.express as px

df = pd.DataFrame({'자산군':['주식', '채권', '현금', '금'],
                  '비율':[25, 25, 25, 25]})
fig = px.pie(df, values = '비율', names='자산군',
             title='영구 포트폴리오', template="plotly_white")
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="07e7de38-a6f5-4637-93c9-26312318ae7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07e7de38-a6f5-4637-93c9-26312318ae7d")) {                    Plotly.newPlot(                        "07e7de38-a6f5-4637-93c9-26312318ae7d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"\uc790\uc0b0\uad70=%{label}<br>\ube44\uc728=%{value}<extra></extra>","labels":["\uc8fc\uc2dd","\ucc44\uad8c","\ud604\uae08","\uae08"],"legendgroup":"","name":"","showlegend":true,"values":[25,25,25,25],"type":"pie","textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scat ...

# %% [markdown]
# ----
# ### 올시즌(올웨더) 포트폴리오
#  - [레이달리오](https://namu.wiki/w/%EB%A0%88%EC%9D%B4%20%EB%8B%AC%EB%A6%AC%EC%98%A4)
#
#
# ```
# 미국의 투자가이자 헤지펀드 매니저. 브리지워터 어소시에이츠 설립자이자 전 CEO.
#
# 20세기에는 워렌 버핏이라면 21세기에는 레이 달리오라 해도 과언이 아닐 정도로 금융계를 선도하는 인물로 금융계의 스티브 잡스라는 별명이 있다.
#
# 2008년 세계 금융 위기 이전에 위기가 올 시기를 1~2개월 오차로 예측해낸 것으로 유명하다.
#
# 2000년 닷컴버블, 2008년 미국발 세계금융위기 에서 성공적으로 포트폴리오를 꾸려
# 현재까지 전 세계 자산 1위(미화 약 15.6억 달러/ 한화 약 18조 원)의 헤지펀드 매니저로서의 명성을 갖고 있다.
#
# 레이 달리오가 만든 올웨더 포트폴리오 전략은 금융계와 개인 투자자들 사이에서 정석으로 꼽힐 정도로 선풍적인 대세 전략으로 꼽히고 있다.
# ```
#
#
#
#
#  - [레이달리오처럼 투자하기, ETF로 하는법](https://blog.toss.im/article/asset-allocation-etf)

# %%
import plotly.express as px

df = pd.DataFrame({'자산군':['리츠', '원자재', '대형주', '소형주', '중형주'],
                  '비율':[40, 30, 15, 10, 5]})
fig = px.pie(df, values = '비율', names='자산군',
             title='올시즌 포트폴리오', template="plotly_white")
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="84d21c85-3adb-414a-8651-dacacacef061" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84d21c85-3adb-414a-8651-dacacacef061")) {                    Plotly.newPlot(                        "84d21c85-3adb-414a-8651-dacacacef061",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"\uc790\uc0b0\uad70=%{label}<br>\ube44\uc728=%{value}<extra></extra>","labels":["\ub9ac\uce20","\uc6d0\uc790\uc7ac","\ub300\ud615\uc8fc","\uc18c\ud615\uc8fc","\uc911\ud615\uc8fc"],"legendgroup":"","name":"","showlegend":true,"values":[40,30,15,10,5],"type":"pie","textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorb ...

# %% [markdown]
# ----
# ### 맞춤형 포트폴리오
#  - 국내/해외 주식을 구분하고, 배당자산을 별도로 설정
#  - 안전자산(60)
#     - 채권(30), 금(20), 달러(10)
#  - 투자자산(20)
#     - 국내주식(10), 해외주식(10)
#  - 배당자산(15)
#  - 현금자산(5)

# %%
import plotly.express as px

df = pd.DataFrame({'자산군':['안전자산', '배당자산', '투자자산', '현금자산'],
                  '비율':[60, 15, 20, 5]})
fig = px.pie(df, values = '비율', names='자산군',
             title='맞춤형 포트폴리오', template="plotly_white")
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="dc53e9f1-46de-47ab-85eb-ac8e26aa5c95" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc53e9f1-46de-47ab-85eb-ac8e26aa5c95")) {                    Plotly.newPlot(                        "dc53e9f1-46de-47ab-85eb-ac8e26aa5c95",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"\uc790\uc0b0\uad70=%{label}<br>\ube44\uc728=%{value}<extra></extra>","labels":["\uc548\uc804\uc790\uc0b0","\ubc30\ub2f9\uc790\uc0b0","\ud22c\uc790\uc790\uc0b0","\ud604\uae08\uc790\uc0b0"],"legendgroup":"","name":"","showlegend":true,"values":[60,15,20,5],"type":"pie","textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{" ...

# %% [markdown]
# ---
# # 실습

# %% [markdown]
# 포트폴리오 기반 거래 일지 만들기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 현금 비중을 0으로 하고, 해외 주식의 비중을 15%로 설정하였습니다.
# - 자산군 별 종목은 위의 내용과 상이할 수 있습니다.

# %%
def create_portfolio_base():
    category = ['채권', '금', '달러', '배당주', '국내주식', '해외주식']
    ratio = [30, 20, 10, 15, 10, 15]
    ticker = [#'438560', #SOL국고채3년
            '305080', #TIGER 미국채10년선물
            '411060', #ACE KRX금현물
            '261240', #KODEX 미국달러선물
            '161510', #ARIRANG 고배당주
            '069660', #KOSEF 200
            '360750' #TIGER 미국S&P500
            ]

    df = pd.DataFrame({'자산군': category,
                    '세팅비중': ratio,
                    '티커': ticker})
    return df

base_df = create_portfolio_base()
base_df
# Out:
#     자산군  세팅비중      티커
# 0    채권    30  305080
# 1     금    20  411060
# 2    달러    10  261240
# 3   배당주    15  161510
# 4  국내주식    10  069660
# 5  해외주식    15  360750

# %%
fig = px.pie(base_df, values = '세팅비중', names='자산군',
             title='맞춤형 포트폴리오', template="plotly_white")
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="058ca5bf-f2b1-41c7-85e2-755f72cb05b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("058ca5bf-f2b1-41c7-85e2-755f72cb05b6")) {                    Plotly.newPlot(                        "058ca5bf-f2b1-41c7-85e2-755f72cb05b6",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"\uc790\uc0b0\uad70=%{label}<br>\uc138\ud305\ube44\uc911=%{value}<extra></extra>","labels":["\ucc44\uad8c","\uae08","\ub2ec\ub7ec","\ubc30\ub2f9\uc8fc","\uad6d\ub0b4\uc8fc\uc2dd","\ud574\uc678\uc8fc\uc2dd"],"legendgroup":"","name":"","showlegend":true,"values":[30,20,10,15,10,15],"type":"pie","textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0 ...

# %% [markdown]
# ### 예상투자금 설정

# %% [markdown]
# 월 100만원을 투자한다고 가정하고,세팅 비중에 따라 자산별 투자금액을 설정합니다.

# %%
def set_monthly_pred_investment(df, total):
    invest_ratio = []
    for i in df['세팅비중']:
        invest_ratio.append(total*i/100)
    df['예상투자금'] = invest_ratio
    return df

# %%
df = set_monthly_pred_investment(base_df, 1000000)
df
# Out:
#     자산군  세팅비중      티커     예상투자금
# 0    채권    30  305080  300000.0
# 1     금    20  411060  200000.0
# 2    달러    10  261240  100000.0
# 3   배당주    15  161510  150000.0
# 4  국내주식    10  069660  100000.0
# 5  해외주식    15  360750  150000.0

# %% [markdown]
# ## 현재 금액 읽어오기
#
# [pykrx 모듈](https://github.com/sharebook-kr/pykrx)을 사용하여 항목별 현재 가격을 읽어옵니다.

# %% [markdown]
# ### 종목명 업데이트
# 티커는 인지하기 어떤 종목인지 인지하기 어려우므로, 종목명을 읽어옵니다.

# %%
from pykrx import stock

def set_etf_name(df):
    name = []
    for i in df['티커']:
        name.append(stock.get_etf_ticker_name(i))
    df['종목명'] = name
    return df

# %%
df = set_etf_name(df)
df
# Out:
#     자산군  세팅비중      티커     예상투자금             종목명
# 0    채권    30  305080  300000.0  TIGER 미국채10년선물
# 1     금    20  411060  200000.0      ACE KRX금현물
# 2    달러    10  261240  100000.0    KODEX 미국달러선물
# 3   배당주    15  161510  150000.0    ARIRANG 고배당주
# 4  국내주식    10  069660  100000.0       KOSEF 200
# 5  해외주식    15  360750  150000.0  TIGER 미국S&P500

# %% [markdown]
# 날짜에 따라 해당 ETF가 운용시작전이었을 수도 있고, 장이 열리지 않는 날일 수 있습니다.
# 운용 시작 전인 경우에는 현재 금액을 0으로 설정하고, 장이 열리지 않는 날인 경우에는 그 다음 날짜를 설정하여 가격을 읽어옵니다.

# %%
from datetime import datetime, timedelta
def set_current_price(df, date):
    flag = True
    ohlcv_df = None
    while flag:
        ohlcv_df = stock.get_etf_ohlcv_by_ticker(date)
        if len(ohlcv_df) == 0:
            if type(date) == str:
                date = datetime.strptime(date, '%Y-%m-%d')
            date_obj = date + timedelta(days=1)
            date = str(date_obj)[:10]
        else:
            flag = False

    price = []
    for i in df['티커']:
        if ohlcv_df.index.isin([i]).sum() > 0:
            price.append(ohlcv_df.loc[i, '종가'])
        else:
            print('{}에 {}가 존재하지 않습니다.'.format(date, i))
            price.append(0)
    df['현재가'] = price
    df['투자날짜'] = str(date)[:10]
    return df

# %%
df = set_current_price(df, '2023-04-10')
df
# Out:
#     자산군  세팅비중      티커     예상투자금             종목명    현재가        투자날짜
# 0    채권    30  305080  300000.0  TIGER 미국채10년선물  11960  2023-04-10
# 1     금    20  411060  200000.0      ACE KRX금현물  12205  2023-04-10
# 2    달러    10  261240  100000.0    KODEX 미국달러선물  11915  2023-04-10
# 3   배당주    15  161510  150000.0    ARIRANG 고배당주  11830  2023-04-10
# 4  국내주식    10  069660  100000.0       KOSEF 200  33205  2023-04-10
# 5  해외주식    15  360750  150000.0  TIGER 미국S&P500  13580  2023-04-10

# %% [markdown]
# ## 보유 수량 설정
#
# `예상투자금`으로 각 종목을 얼마나 구매 가능한 지 보유수량을 결정합니다.
# `수량`은 `예상투자금`을 `현재가`로 나누어 반올림하여 정하였습니다.
# 따라서 실제 투자금은 `예상투자금`보다 클 수 있습니다.

# %%
def get_volume(df):
    df['수량'] = np.round(df['예상투자금']/df['현재가'])
    df['수량'].replace(np.inf, 0, inplace= True)
    df['수량'] = df['수량'].astype(int)
    return df

# %%
df = get_volume(df)
df
# Out:
#     자산군  세팅비중      티커     예상투자금             종목명    현재가        투자날짜  수량
# 0    채권    30  305080  300000.0  TIGER 미국채10년선물  11960  2023-04-10  25
# 1     금    20  411060  200000.0      ACE KRX금현물  12205  2023-04-10  16
# 2    달러    10  261240  100000.0    KODEX 미국달러선물  11915  2023-04-10   8
# 3   배당주    15  161510  150000.0    ARIRANG 고배당주  11830  2023-04-10  13
# 4  국내주식    10  069660  100000.0       KOSEF 200  33205  2023-04-10   3
# 5  해외주식    15  360750  150000.0  TIGER 미국S&P500  13580  2023-04-10  11

# %% [markdown]
# ## 실투자금 업데이트
#
#  위에서 계산한 종목별 `수량`에 따라 `현재가`로 구매했을 시, 실제 발생한 투자금을 업데이트 합니다. 실제 투자금은 수수료가 추가로 부가되지만, 수수료에 대한 부분은 고려하지 않았습니다.

# %%
def get_monthly_investment(df):
    df['실투자금'] = df['현재가']*df['수량']
    return df

# %%
df = get_monthly_investment(df)
df
# Out:
#     자산군  세팅비중      티커     예상투자금             종목명    현재가        투자날짜  수량    실투자금
# 0    채권    30  305080  300000.0  TIGER 미국채10년선물  11960  2023-04-10  25  299000
# 1     금    20  411060  200000.0      ACE KRX금현물  12205  2023-04-10  16  195280
# 2    달러    10  261240  100000.0    KODEX 미국달러선물  11915  2023-04-10   8   95320
# 3   배당주    15  161510  150000.0    ARIRANG 고배당주  11830  2023-04-10  13  153790
# 4  국내주식    10  069660  100000.0       KOSEF 200  33205  2023-04-10   3   99615
# 5  해외주식    15  360750  150000.0  TIGER 미국S&P500  13580  2023-04-10  11  149380

# %%
sum(df['실투자금'])
# Out:
# 992385

# %% [markdown]
# ----

# %% [markdown]
# # 일자별 투자 리포트 생성하기

# %% [markdown]
# 위에서 설정한 로직을 수행하는 함수를 생성합니다.

# %%
def get_portfolio_by_date(total, date):
    base_df = create_portfolio_base()
    df = set_monthly_pred_investment(base_df, total)
    df = set_etf_name(df)
    df = set_current_price(df, date)
    df = get_volume(df)
    df = get_monthly_investment(df)
    return df

# %%
april_df = get_portfolio_by_date(800000, '20230410')
april_df
# Out:
#     자산군  세팅비중      티커     예상투자금             종목명    현재가      투자날짜  수량    실투자금
# 0    채권    30  305080  240000.0  TIGER 미국채10년선물  11960  20230410  20  239200
# 1     금    20  411060  160000.0      ACE KRX금현물  12205  20230410  13  158665
# 2    달러    10  261240   80000.0    KODEX 미국달러선물  11915  20230410   7   83405
# 3   배당주    15  161510  120000.0    ARIRANG 고배당주  11830  20230410  10  118300
# 4  국내주식    10  069660   80000.0       KOSEF 200  33205  20230410   2   66410
# 5  해외주식    15  360750  120000.0  TIGER 미국S&P500  13580  20230410   9  122220

# %% [markdown]
# ----

# %% [markdown]
# ## 기간별 수익률 계산
# - 2022년 1월 1일부터 2023년 4월 10일까지 매달 초에 한 번씩 투자를 진행했을 경우 수익률을 계산합니다. 월투자금은 22년 1월, 22년 7월, 23년 1월에는 100만원으로 늘려서 설정하였습니다.

# %%
history_df = pd.DataFrame(columns= ['날짜'], 
                          data = pd.date_range('2022-01-01', '2023-04-10', freq='BMS'))
history_df['월투자금']=800000
history_df.iloc[[0,6,12], 1]=1000000

# %%
history_df
# Out:
#            날짜     월투자금
# 0  2022-01-03  1000000
# 1  2022-02-01   800000
# 2  2022-03-01   800000
# 3  2022-04-01   800000
# 4  2022-05-02   800000
# 5  2022-06-01   800000
# 6  2022-07-01  1000000
# 7  2022-08-01   800000
# 8  2022-09-01   800000
# 9  2022-10-03   800000
# 10 2022-11-01   800000
# 11 2022-12-01   800000
# 12 2023-01-02  1000000
# 13 2023-02-01   800000
# 14 2023-03-01   800000
# 15 2023-04-03   800000

# %%
def get_balance(df):
    total_df = None
    value_list= []
    for index, d in df.iterrows():
        month_df = get_portfolio_by_date(d['월투자금'], d['날짜'])
        # display(month_df)
        # print(month_df['실투자금'].sum())
        if total_df is None:
            total_df = month_df
        else:
            total_df = pd.concat([total_df, month_df])      
    
        volumes = total_df.groupby(['종목명']).sum()['수량']
        monthly_value = 0
        for index, value in volumes.iteritems():
            price = month_df.query("종목명 == '{}'".format(index))['현재가'].values
            monthly_value += price * value
        value_list.extend(monthly_value)

    df['월투자금'] = total_df.groupby(['투자날짜']).sum()['실투자금'].values
    df['평가금액'] = value_list
    return total_df, df

# %%
total_df, history_df = get_balance(history_df)
history_df['누적투자금'] = history_df['월투자금'].cumsum()
history_df['수익률'] = history_df['평가금액']/history_df['누적투자금']
# Out:
# <ipython-input-32-d3f4f1b3ffdd>:13: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# <ipython-input-32-d3f4f1b3ffdd>:15: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# <ipython-input-32-d3f4f1b3ffdd>:13: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# <ipython-input-32-d3f4f1b3ffdd>:15: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# <ipython-input-32-d3f4f1b3ffdd>:13: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# <ipython-input-32-d3f4f1b3ffdd>:15: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# <ipython-input-32-d3f4f1b3ffdd>:13: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# <ipython-input-32-d3f4f1b3ffdd>:15: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# <ipython-input-32-d3f4f1b3ffdd>:13: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# <ipython-input-32-d3f4f1b3ffdd>:15: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# <ipython-input-32-d3f4f1b3ffdd>:13: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# <ipython-input-32-d3f4f1b3ffdd>:15: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# <ipython-input-32-d3f4f1b3ffdd>:13: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# <ipython-input-32-d3f4f1b3ffdd>:15: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# <ipython-input-32-d3f4f1b3ffdd>:13: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# <ipython-input-32-d3f4f1b3ffdd>:15: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# <ipython-input-32-d3f4f1b3ffdd>:13: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# <ipython-input-32-d3f4f1b3ffdd>:15: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# <ipython-input-32-d3f4f1b3ffdd>:13: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# <ipython-input-32-d3f4f1b3ffdd>:15: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# <ipython-input-32-d3f4f1b3ffdd>:13: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# <ipython-input-32-d3f4f1b3ffdd>:15: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# <ipython-input-32-d3f4f1b3ffdd>:13: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# <ipython-input-32-d3f4f1b3ffdd>:15: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# <ipython-input-32-d3f4f1b3ffdd>:13: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# <ipython-input-32-d3f4f1b3ffdd>:15: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# <ipython-input-32-d3f4f1b3ffdd>:13: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# <ipython-input-32-d3f4f1b3ffdd>:15: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# <ipython-input-32-d3f4f1b3ffdd>:13: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# <ipython-input-32-d3f4f1b3ffdd>:15: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# <ipython-input-32-d3f4f1b3ffdd>:13: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# <ipython-input-32-d3f4f1b3ffdd>:15: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# <ipython-input-32-d3f4f1b3ffdd>:20: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %%
history_df
# Out:
#            날짜     월투자금      평가금액     누적투자금       수익률
# 0  2022-01-03  1017345   1017345   1017345  1.000000
# 1  2022-02-01   802320   1802740   1819665  0.990699
# 2  2022-03-01   805780   2617385   2625445  0.996930
# 3  2022-04-01   802125   3447105   3427570  1.005699
# 4  2022-05-02   793885   4198740   4221455  0.994619
# 5  2022-06-01   794290   4936595   5015745  0.984220
# 6  2022-07-01   983400   5823525   5999145  0.970726
# 7  2022-08-01   783095   6739065   6782240  0.993634
# 8  2022-09-01   827765   7573410   7610005  0.995191
# 9  2022-10-03   794800   8425405   8404805  1.002451
# 10 2022-11-01   820430   9251420   9225235  1.002838
# 11 2022-12-01   789695   9897525  10014930  0.988277
# 12 2023-01-02   985520  10529355  11000450  0.957175
# 13 2023-02-01   799880  11543115  11800330  0.978203
# 14 2023-03-01   789440  12520550  12589770  0.994502
# 15 2023-04-03   789340  13676900  13379110  1.022258

# %%
total_df['투자날짜'] = pd.to_datetime(total_df['투자날짜'])
total_df.set_index('투자날짜', inplace = True)
total_df
# Out:
#              자산군  세팅비중      티커     예상투자금             종목명    현재가  수량    실투자금
# 투자날짜
# 2022-01-03    채권    30  305080  300000.0  TIGER 미국채10년선물  12145  25  303625
# 2022-01-03     금    20  411060  200000.0      ACE KRX금현물  10255  20  205100
# 2022-01-03    달러    10  261240  100000.0    KODEX 미국달러선물  10545   9   94905
# 2022-01-03   배당주    15  161510  150000.0    ARIRANG 고배당주  12510  12  150120
# 2022-01-03  국내주식    10  069660  100000.0       KOSEF 200  39965   3  119895
# ...          ...   ...     ...       ...             ...    ...  ..     ...
# 2023-04-03     금    20  411060  160000.0      ACE KRX금현물  11800  14  165200
# 2023-04-03    달러    10  261240   80000.0    KODEX 미국달러선물  11905   7   83335
# 2023-04-03   배당주    15  161510  120000.0    ARIRANG 고배당주  11865  10  118650
# 2023-04-03  국내주식    10  069660   80000.0       KOSEF 200  32565   2   65130
# 2023-04-03  해외주식    15  360750  120000.0  TIGER 미국S&P500  13525   9  121725
#
# [96 rows x 8 columns]

# %% [markdown]
# ## 날짜별 각 종목 투자 현황

# %%
pd.pivot_table(total_df, values = '수량', 
               index = '투자날짜', columns = '종목명',
               aggfunc = np.sum)
# Out:
# 종목명         ACE KRX금현물  ARIRANG 고배당주  KODEX 미국달러선물  KOSEF 200  TIGER 미국S&P500  \
# 투자날짜
# 2022-01-03          20            12             9          3              10
# 2022-02-03          16            10             7          2               9
# 2022-03-02          15            10             8          2               9
# 2022-04-01          15             9             7          2               9
# 2022-05-02          14            10             7          2               9
# 2022-06-02          15            10             7          2               9
# 2022-07-01          18            13             9          3              12
# 2022-08-01          15            11             7          2               9
# 2022-09-01          15            11             7          3               9
# 2022-10-04          14            11             6          3               9
# 2022-11-01          15            11             6          3               9
# 2022-12-01          15            10             7          2               9
# 2023-01-02          18            13             9          3              12
# 2023-02-01          15            10             7          2              10
# 2023-03-02          15            10             7          2               9
# 2023-04-03          14            10             7          2               9
#
# 종목명         TIGER 미국채10년선물
# 투자날짜
# 2022-01-03              25
# 2022-02-03              20
# 2022-03-02              20
# 2022-04-01              21
# 2022-05-02              21
# 2022-06-02              21
# 2022-07-01              25
# 2022-08-01              19
# 2022-09-01              20
# 2022-10-04              19
# 2022-11-01              20
# 2022-12-01              21
# 2023-01-02              27
# 2023-02-01              22
# 2023-03-02              21
# 2023-04-03              20

# %% [markdown]
# ## 종목별 가격 시각화

# %%
etf_pivot = pd.pivot_table(total_df, values = '현재가', 
               index = '투자날짜', columns = '종목명',
               aggfunc = np.sum)
etf_pivot
# Out:
# 종목명         ACE KRX금현물  ARIRANG 고배당주  KODEX 미국달러선물  KOSEF 200  TIGER 미국S&P500  \
# 투자날짜
# 2022-01-03       10255         12510         10545      39965           14370
# 2022-02-03       10265         12500         10670      36630           13770
# 2022-03-02       10810         12595         10655      36520           13100
# 2022-04-01       10980         13310         10745      36830           13930
# 2022-05-02       11140         12490         11180      35320           13205
# 2022-06-02       10800         12530         11075      35025           12915
# 2022-07-01       10865         11220         11480      30510           12260
# 2022-08-01       10640         11155         11550      32410           13470
# 2022-09-01       10675         11185         12010      31535           13370
# 2022-10-04       11130         10705         12650      28965           13310
# 2022-11-01       10840         11095         12600      30360           13845
# 2022-12-01       10765         12055         11590      32280           13305
# 2023-01-02       10885         11300         11375      29375           12280
# 2023-02-01       11005         12410         11055      32570           12530
# 2023-03-02       11030         12200         11820      32025           12960
# 2023-04-03       11800         11865         11905      32565           13525
#
# 종목명         TIGER 미국채10년선물
# 투자날짜
# 2022-01-03           12145
# 2022-02-03           12060
# 2022-03-02           12075
# 2022-04-01           11590
# 2022-05-02           11680
# 2022-06-02           11580
# 2022-07-01           12000
# 2022-08-01           12310
# 2022-09-01           12280
# 2022-10-04           12560
# 2022-11-01           12225
# 2022-12-01           11535
# 2023-01-02           11290
# 2023-02-01           11040
# 2023-03-02           11360
# 2023-04-03           11765

# %%
etf_pivot.plot(figsize=(18,5))
# Out:
# <Axes: xlabel='투자날짜'>
